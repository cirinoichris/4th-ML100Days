# %% [markdown]
# ## 讀取 txt 檔
# * 請讀取 [text file](https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt)
# * 懶人複製連結: https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt
#
# ### Hints: 使用 [Request](https://blog.gtwang.org/programming/python-requests-module-tutorial/) 抓取資料
# ### Hints: [字串分割](http://www.runoob.com/python/att-string-split.html)
# ### Hints: 例外處理: [Try-Except](https://pydoing.blogspot.com/2011/01/python-try.html)

# %% [markdown]
# # [作業目標]
# - 試著讀取網頁上的圖片連結清單, 再以清單中網址讀取圖片

# %% [markdown]
# # [作業重點]
# - 從網頁上讀取連結清單 (In[1], In[2])
# - 從清單網址讀取圖片 (In[6]~In[9], Out[6]~Out[9])

# %%
## 假如我們不想把資料載到自己的電腦裡?
# 把連結填入
target_url = 'https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt'

# %%
import requests
response = requests.get(target_url)
data = response.text

# 用 request 傳送回來的資料不會認得斷行符號
print(len(data))
data[0:100]
# Out:
# 784594
# 'n00015388_157\thttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238\thttp://farm2'

# %%
## 取代 \t 為 \n
data = data.replace('\t', '\n');data
# Out:
# "n00015388_157\nhttp://farm1.static.flickr.com/145/430300483_21e993670c.jpg\nn00015388_238\nhttp://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg\nn00015388_304\nhttp://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg\nn00015388_327\nhttp://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg\nn00015388_355\nhttp://img100.imageshack.us/img100/3253/forrest004fs9.jpg\nn00015388_373\nhttp://img172.imageshack.us/img172/4606/napo03072en9.jpg\nn00015388_379\nhttp://fotootjesvanannelies.web-log.nl/olifantfotootjes/images/2008/06/04/img_8870.jpg\nn00015388_388\nhttp://www.deweekkrant.nl/images/library/pictures/4f/2e/a5/cf/2_3d81b762a5e8a345bbb1f0884fab2e9762146129.jpg\nn00015388_442\nhttp://www.porschemania.it/discus/messages/815/102099.jpg\nn00015388_474\nhttp://farm1.static.flickr.com/72/225029238_805b0937ca.jpg\nn00015388_514\nhttp://farm2.static.flickr.com/1128/1432436038_6c131f1bb0.jpg\nn00015388_671\nhttp://farm4.static.flickr.com/3217/2942611930_d68204f726.jpg\nn00015388_686\nhttp://farm1.static.flickr.com/29/54608382_ee8bd4f7fa.jpg\nn00015388_706\nhttp://www.dierentuin.nl/images/jongengiraffe.jpg\nn00015388_725\nhttp://farm4.static.flickr.com/3279/3118047175_259ab89c92.jpg\nn00015388_758\nhttps://w3f7yg.bay.livefilest
286\nhttp://www.photophoto.cn/m72/018/056/0180560156.jpg\nn00015388_2423\nhttp://larrestodelcarlino.myblog.it/media/00/01/596222212.jpg\nn00015388_2436\nhttp://www.digitalegroetjes.nl/kaartjes/images/67588held.jpg\nn00015388_2506\nhttp://farm4.static.flickr.com/3590/3400746484_3dd2f91246.jpg\nn00015388_2544\nhttp://media.zobrabant.nl:81/img/dyn/c1df79c81185d378ca5b284480961e46_200x131.jpg\nn00015388_2594\nhttp://farm1.static.flickr.com/71/214363 ...

# %%
# 找到換行符號，用該符號做字串分割後，把它拿掉
split_tag ='\n' 
data = data.split(split_tag)
print(len(data))
data[0]
# Out:
# 19991
# 'n00015388_157'

# %%
data[data.index%2==1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-55bc552aa726> in <module>()
# ----> 1 data[data.index%2==1]
#
# TypeError: unsupported operand type(s) for %: 'builtin_function_or_method' and 'int'

# %%
df = pd.DataFrame(data);df[:2]
# Out:
#                                                    0
# 0                                      n00015388_157
# 1  http://farm1.static.flickr.com/145/430300483_2...

# %%
## 保留偶数行，删除奇数行
df=df[df.index%2==1];df[0]
# Out:
# 1        http://farm1.static.flickr.com/145/430300483_2...
# 3        http://farm2.static.flickr.com/1005/3352960681...
# 5        http://farm1.static.flickr.com/27/51009336_a96...
# 7        http://farm4.static.flickr.com/3025/2444687979...
# 9        http://img100.imageshack.us/img100/3253/forres...
# 11       http://img172.imageshack.us/img172/4606/napo03...
# 13       http://fotootjesvanannelies.web-log.nl/olifant...
# 15       http://www.deweekkrant.nl/images/library/pictu...
# 17       http://www.porschemania.it/discus/messages/815...
# 19       http://farm1.static.flickr.com/72/225029238_80...
# 21       http://farm2.static.flickr.com/1128/1432436038...
# 23       http://farm4.static.flickr.com/3217/2942611930...
# 25       http://farm1.static.flickr.com/29/54608382_ee8...
# 27       http://www.dierentuin.nl/images/jongengiraffe.jpg
# 29       http://farm4.static.flickr.com/3279/3118047175...
# 31       https://w3f7yg.bay.livefilestore.com/y1miLTQmc...
# 33       http://farm4.static.flickr.com/3271/2496428562...
# 35       http://farm2.static.flickr.com/1115/703274169_...
# 37       http://farm1.static.flickr.com/70/200362625_93...
# 39       http://farm1.static.flickr.com/180/370761991_7...
# 41       http://farm3.static.flickr.com/2197/1659368303...
# 43       http://home.planet.nl/~huske073/Dieren/dier-si...
# 45       http://www.joanranquet.com/images/AnimalNews-L...
# 47       http://www.wereldomroep.nl/images/assets/10707839
# 49       http://farm4.static.flickr.com/3231/2858342976...
# 51       http://farm3.static.flickr.com/2188/2086791140...
# 53       http://farm2.static.flickr.com/1140/950904728_...
# 55       http://www.dierenrijk.nl/uploads/media/620x248...
# 57       http://farm4.static.flickr.com/3107/2652244127...
# 59       http://fotootjesvanannelies.web-log.nl/olifant...
#                                ...
# 19931    http://i413.photobucket.com/albums/pp212/gymgi...
# 19933    http://www2.pictures.gi.zimbio.com/2008+Olympi...
# 19935    http://images1.fanpop.com/images/photos/200000...
# 19937    http://www.triadgymnastics.com/Teams/Junior%20...
# 19939    http://home.global.co.za/~tyshler/pictures/gym...
# 19941    http://news.jongo.com/articles/07/0319/9500/21...
# 19943    http://static.flickr.com/3026/3016579222_83864...
# 19945    http://www.grampianspyrenees.com.au/Page/Image...
# 19947    http://www.graceclick.ca/images/Yorke1599_72dp...
# 19949    http://photos.upi.com/story/w/c8b6912ae0806acd...
# 19951    http://www3.pictures.gi.zimbio.com/2008+Olympi...
# 19953    http://static.flickr.com/3206/3015742771_eeb85...
# 19955    http://www.sportovniaerobik.cz/upload.en/9/98a...
# 19957    http://www.oasisgym.com/UploadImages/tn_PICT17...
# 19959    http://static.flickr.com/2148/2463933378_02468...
# 19961    http://www.glasgowschoolofsportbellahoustonaca...
# 19963    http://static.flickr.com/3523/3318629730_4797b...
# 19965    http://static.flickr.com/179/420123133_2e40f7b...
# 19967    http://static.flickr.com/101/313434378_5d928b0...
# 19969            http://www.ddgym.com/images/kidbounce.jpg
# 19971          http://creativeplayrooms.com/gymnastics.jpg
# 19973    http://static.flickr.com/3078/3089444592_73c67...
# 19975    http://www.glendale.k12.wi.us/Domains/glendale...
# 19977    http://media.thesunnews.com/smedia/2009/02/14/...
# 19979    http://static.flickr.com/3451/3278255172_fbd2a...
# 19981    http://grfx.cstv.com/photos/schools/afa/sports...
# 19983    http://farm2.static.flickr.com/1130/960179413_...
# 19985    http://static.flickr.com/150/387324732_f8149d0...
# 19987    http://3.bp.blogspot.com/_9T2cRtlgHV0/SK55RHay...
# 19989    http://www.loudoungymnastics.com/images/Girls_...
# Name: 0, Length: 9995, dtype: object

# %% [markdown]
# ## 將 txt 轉成 pandas dataframe

# %%
import pandas as pd

# %%
df = pd.DataFrame(arrange_data)
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-03de35e4a257> in <module>()
# ----> 1 df = pd.DataFrame(arrange_data)
#       2 df.head()
#
# NameError: name 'arrange_data' is not defined

# %% [markdown]
# ## 讀取圖片，請讀取上面 data frame 中的前 5 張圖片

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# %%
# 請用 df.loc[...] 得到第一筆資料的連結
first_link = 

response = requests.get(first_link)
img = Image.open(BytesIO(response.content))

# Convert img to numpy array

plt.imshow(img)
plt.show()

# %%
def img2arr_fromURLs(url_list, resize = False):
    """
    請完成這個 Function
    Args
        - url_list: list of URLs
        - resize: bool
    Return
        - list of array
    """
    
    return img_list

# %%
result = img2arr_fromURLs(df[0:5][1].values)
print("Total images that we got: %i " % len(result)) # 如果不等於 5, 代表有些連結失效囉

for im_get in result:
    plt.imshow(im_get)
    plt.show()
